# %%
# %run back_testing/ma/main.py
# Out:
# --- Data Loading for: NSEI ---
# Requested Range: 2001-01-01 to 2020-12-31
# File availability: 2015-01-08 to 2025-10-31
# Final loaded range: 2015-01-08 to 2020-12-31
# Total rows loaded: 1481
# --- Running Initial Backtest for NSEI ---
# Buy and hold returns: 3.0
# Strategy returns: 1.79
# <h4>Performance Metrics</h4>
# Parameter       Value
# --------------  ---------
# Benchmark       Benchmark
# Risk-Free Rate  0.0%
# Periods/Year    252
# Compounded      Yes
# Match Dates     Yes
#
#
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2015-05-08   2015-05-08
# End Period                 2020-12-31   2020-12-31
# Risk-Free Rate             0.0%         0.0%
# Time in Market             99.0%        68.0%
#
# Cumulative Return          298.6%       79.4%
# CAGR﹪                     28.24%       11.08%
#
# Sharpe                     0.73         0.45
# Prob. Sharpe Ratio         95.87%       86.13%
# ...
